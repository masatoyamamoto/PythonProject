# %%
import pandas as pd
import matplotlib.pyplot as plt 
df = pd.read_csv("./Data/Data.csv",encoding="utf-8")
df = df.drop(df.columns[[0]],axis=1)
df.columns.values
# Out:
# array(['name', 'size', 'terrace', 'age_1', 'ku', 'room', 'Living',
#        'Dining', 'Kitchen', 'Service', 'No.ofRooms', 'price'],
#       dtype=object)

# %%
df.plot(x="ku",y="price",kind="scatter",rot=50)
# Out:
# <AxesSubplot:xlabel='ku', ylabel='price'>
